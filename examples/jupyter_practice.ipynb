# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 2.5.2

# %%
# %timeit [x for x in range(100000)]
# Out:
# 1.46 ms ± 94.8 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit np.arange(100000)
# Out:
# 22.2 μs ± 139 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# # My Jupyter Notebook
#
# ## Python vs NumPy
#
# This notebook compares Python operations with NumPy operations using `%timeit`.

# %%
import pandas as pd

df = pd.DataFrame({
    "model": ["Linear", "Random Forest", "Neural Net"],
    "accuracy": [0.72, 0.89, 0.94],
    "training_time": [0.1, 2.3, 45.6]
})

df
# Out:
#            model  accuracy  training_time
# 0         Linear      0.72            0.1
# 1  Random Forest      0.89            2.3
# 2     Neural Net      0.94           45.6

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))

plt.plot(
    [1, 2, 3, 4],
    [1, 2, 3, 4]
)

plt.title("Inline Plot")

plt.show()

# %%
# %timeit np.random.random(10000)
# Out:
# 30.6 μs ± 123 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%time

data = np.random.randn(1000000)
result = data.mean()

print(result)
# Out:
# -0.000837125287334863
# CPU times: user 6.71 ms, sys: 12.5 ms, total: 19.2 ms
# Wall time: 17.7 ms
